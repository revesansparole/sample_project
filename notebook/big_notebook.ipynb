# %% [markdown]
# Sky is the limit
# ================

# %% [markdown]
# Project aiming at looking around to discover remnants of galaxy explosions in our surrounding.
#
# > Chaque atome trouvé sur le bord du chemin
# > Fut soleil rayonnant, étoile du matin.
# > Brosse donc sur ta manche humblement la poussière:
# > Un beau visage est là, caché dans chaque grain.
# >
# > -- <cite>Les chants d'Omar Khayam</cite>

# %%
import something_that_do_not_exists
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-9f6ddd0775db> in <module>()
# ----> 1 import something_that_do_not_exists
#
# ImportError: No module named something_that_do_not_exists

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from math import pi
from numpy import arange, sin

t = arange(40000) / 20000.

f_message = 1 # Hz
def message(t):
    return sin(2 * pi * f_message * t)

f_carrier = 10 # Hz
carrier = sin(2 * pi * f_carrier * t)

# %% [markdown]
# Amplitude modulation
# --------------------

# %%
signal = carrier * message(t)

# %%
plt.subplot(2, 1, 1)
plt.plot(t, signal)
plt.subplot(2, 1, 2)
plt.plot(t, carrier)

# %% [markdown]
# Frequency modulation
# --------------------

# %%
def modulation(amplitude):
    return 0.05 * amplitude

signal = sin(2 * pi * f_carrier * (1 + modulation(message(t))) * t)

# %%
plt.subplot(2, 1, 1)
plt.plot(t, signal)
plt.subplot(2, 1, 2)
plt.plot(t, carrier)
